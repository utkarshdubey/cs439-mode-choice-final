# %% [markdown]
# # Reproduce CS439 Final Project Results
# Run the next cell from the repository root to regenerate all result CSVs and figures.

# %%
# %run ../src/run_project.py

# %% [markdown]
# Generated files will appear in `../results/` and `../figures/`.
